# %% [markdown]
# <a href="https://colab.research.google.com/github/LuvBhardwaj52/data-science-lab-exp01/blob/main/Pandas_Series_Assignment_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from pandas import Series

# %% [markdown]
# ## 1

# %%
sales = Series([120, 150, 180, 210])
sales
# Out:
# 0    120
# 1    150
# 2    180
# 3    210
# dtype: int64

# %% [markdown]
# ## 2

# %%
marks = Series([72, 81, 69, 90])
marks.values
# Out:
# array([72, 81, 69, 90])

# %% [markdown]
# ## 3

# %%
marks.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# ## 4

# %%
temperatures = Series([28, 31, 30, 29], index=['Mon', 'Tue', 'Wed', 'Thu'])
temperatures
# Out:
# Mon    28
# Tue    31
# Wed    30
# Thu    29
# dtype: int64

# %% [markdown]
# ## 5

# %%
population = Series([35, 42, 31], index=['Delhi', 'Mumbai', 'Jaipur'])
population['Jaipur']
# Out:
# np.int64(31)

# %% [markdown]
# ## 6

# %%
score = Series([35, 68, 44, 79, 52])
score[score > 50]
# Out:
# 1    68
# 3    79
# 4    52
# dtype: int64

# %% [markdown]
# ## 7

# %%
subjects = Series([76, 83, 91], index=['Physics', 'Chemistry', 'Maths'])
'Chemistry' in subjects.index
# Out:
# True

# %% [markdown]
# ## 8

# %%
s = Series([10, 20, 30])
s.to_dict()
# Out:
# {0: 10, 1: 20, 2: 30}

# %% [markdown]
# ## 9

# %%
prices = {'Pen': 10, 'Notebook': 55, 'Bag': 700}
price_series = Series(prices)
price_series
# Out:
# Pen          10
# Notebook     55
# Bag         700
# dtype: int64

# %% [markdown]
# ## 10

# %%
prices = {'Pen': 10, 'Notebook': 55, 'Bag': 700}
Series(prices).index
# Out:
# Index(['Pen', 'Notebook', 'Bag'], dtype='object')

# %% [markdown]
# ## 11

# %%
data = {'A': 10, 'B': 20, 'C': 30}
s = Series(data, index=['A', 'B', 'C', 'D'])
s
# Out:
# A    10.0
# B    20.0
# C    30.0
# D     NaN
# dtype: float64

# %% [markdown]
# ## 12

# %%
pd.isnull(s)
# Out:
# A    False
# B    False
# C    False
# D     True
# dtype: bool

# %% [markdown]
# ## 13

# %%
pd.notnull(s)
# Out:
# A     True
# B     True
# C     True
# D    False
# dtype: bool

# %% [markdown]
# ## 14

# %%
sales = Series([120, 150, 180])
sales.name = 'Monthly Sales'
sales
# Out:
# 0    120
# 1    150
# 2    180
# Name: Monthly Sales, dtype: int64

# %% [markdown]
# ## 15

# %%
sales = Series([120, 150, 180])
sales.index.name = 'Month'
sales
# Out:
# Month
# 0    120
# 1    150
# 2    180
# dtype: int64

# %% [markdown]
# ## 16

# %%
s = Series([18, 45, 27, 61], index=['P', 'Q', 'R', 'S'])
s[s > 30]
# Out:
# Q    45
# S    61
# dtype: int64

# %% [markdown]
# ## 17

# %%
s = Series([500, 600, 700], index=['East', 'West', 'North'])
('West' in s, 500 in s)
# Out:
# (True, False)

# %% [markdown]
# ## 18

# %%
city_data = {'Delhi': 80, 'Pune': 65, 'Kochi': 70}
city_series = Series(city_data, index=['Delhi', 'Kochi', 'Pune', 'Chennai'])
city_series
# Out:
# Delhi      80.0
# Kochi      70.0
# Pune       65.0
# Chennai     NaN
# dtype: float64

# %% [markdown]
# ## 19

# %%
s = Series({'W': 5, 'X': 10, 'Y': 15}, index=['W', 'X', 'Y', 'Z'])
pd.isnull(s)
# Out:
# W    False
# X    False
# Y    False
# Z     True
# dtype: bool

# %% [markdown]
# ## 20

# %%
pd.notnull(s)
# Out:
# W     True
# X     True
# Y     True
# Z    False
# dtype: bool

# %% [markdown]
# ## 21

# %%
s1 = Series([10, 20, 30], index=['A', 'B', 'C'])
s2 = Series([1, 2, 3], index=['C', 'A', 'B'])
s1 + s2
# Out:
# A    12
# B    23
# C    31
# dtype: int64

# %% [markdown]
# ## 22

# %%
s1 = Series({'A': 12, 'B': 18})
s2 = Series({'B': 5, 'C': 9})
s1 + s2
# Out:
# A     NaN
# B    23.0
# C     NaN
# dtype: float64

# %% [markdown]
# ## 23

# %%
stock = Series([25, 40, 18], index=['Item1', 'Item2', 'Item3'])
stock_dict = stock.to_dict()
stock2 = Series(stock_dict)
stock_dict, stock2
# Out:
# ({'Item1': 25, 'Item2': 40, 'Item3': 18},
#  Item1    25
#  Item2    40
#  Item3    18
#  dtype: int64)

# %% [markdown]
# ## 24

# %%
marks = {'Maths': 88, 'Science': 74, 'English': 69, 'History': 81}
marks_series = Series(marks, index=['History', 'English', 'Science', 'Maths'])
marks_series[marks_series > 70]
# Out:
# History    81
# Science    74
# Maths      88
# dtype: int64

# %% [markdown]
# ## 25

# %%
rev = Series([100, 200, 300], index=['A', 'B', 'C'])
rev.name = 'Revenue'
rev.index.name = 'Branch'
rev
# Out:
# Branch
# A    100
# B    200
# C    300
# Name: Revenue, dtype: int64

# %% [markdown]
# ## 26

# %%
north = Series({'Jan': 40, 'Feb': 55, 'Mar': 60})
south = Series({'Feb': 20, 'Mar': 25, 'Apr': 30})
total = north + south
total
# Out:
# Apr     NaN
# Feb    75.0
# Jan     NaN
# Mar    85.0
# dtype: float64

# %% [markdown]
# ## 27

# %%
d = {'Red': 12, 'Blue': 18, 'Green': 24}
labels = ['Green', 'Red', 'Yellow', 'Blue']
result = Series(d, index=labels)
result, pd.isnull(result), result.dropna()
# Out:
# (Green     24.0
#  Red       12.0
#  Yellow     NaN
#  Blue      18.0
#  dtype: float64,
#  Green     False
#  Red       False
#  Yellow     True
#  Blue      False
#  dtype: bool,
#  Green    24.0
#  Red      12.0
#  Blue     18.0
#  dtype: float64)

# %% [markdown]
# ## 28

# %%
s = Series([90, 75, 82], index=['Ravi', 'Aman', 'Neha'])
d = s.to_dict()
s2 = Series(d)
s2, s.equals(s2)
# Out:
# (Ravi    90
#  Aman    75
#  Neha    82
#  dtype: int64,
#  True)

# %% [markdown]
# ## 29

# %%
products = Series([650, 420, 800, 350], index=['Laptop', 'Mouse', 'Printer', 'Keyboard'])
products.values
products.index
products['Printer']
products[products > 500]
'Laptop' in products.index
products.to_dict()
# Out:
# {'Laptop': 650, 'Mouse': 420, 'Printer': 800, 'Keyboard': 350}

# %% [markdown]
# ## 30

# %%
data = {'A': 15, 'B': 35, 'C': 25}
s = Series(data, index=['C', 'A', 'D', 'B'])
s.name = 'Observations'
s.index.name = 'Category'
s.index, s, s[s > 20], pd.notnull(s), s.name, s.index.name
# Out:
# (Index(['C', 'A', 'D', 'B'], dtype='object', name='Category'),
#  Category
#  C    25.0
#  A    15.0
#  D     NaN
#  B    35.0
#  Name: Observations, dtype: float64,
#  Category
#  C    25.0
#  B    35.0
#  Name: Observations, dtype: float64,
#  Category
#  C     True
#  A     True
#  D    False
#  B     True
#  Name: Observations, dtype: bool,
#  'Observations',
#  'Category')

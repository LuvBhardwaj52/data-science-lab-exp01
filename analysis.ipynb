# %%
import pandas as pd
df = pd.read_csv('bdi_and_screen_items.csv')
df.head()
df.info()
df.describe()
df.isnull().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4810 entries, 0 to 4809
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   subject_id               4810 non-null   int64
#  1   screen_normal_day_1to6   4810 non-null   int64
#  2   screen_weekday_1to6      4810 non-null   int64
#  3   screen_weekend_1to6      4810 non-null   int64
#  4   sqi_fall_asleep_1to6     4810 non-null   int64
#  5   sqi_repeated_awake_1to6  4810 non-null   int64
#  6   sqi_disturbed_1to6       4810 non-null   int64
#  7   sqi_early_awake_1to6     4810 non-null   int64
#  8   bdi_item_01              4810 non-null   int64
#  9   bdi_item_02              4810 non-null   int64
#  10  bdi_item_03              4810 non-null   int64
#  11  bdi_item_04              4810 non-null   int64
#  12  bdi_item_05              4810 non-null   int64
#  13  bdi_item_06              4810 non-null   int64
# ...
